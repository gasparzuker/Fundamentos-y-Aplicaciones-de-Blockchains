# %% [markdown]
# # Generacion de voto
# Correr estos scripts correctamente genera un input de voto cifrado y las ZKP necesarias para hacer la transacción en Sepolia y efectuar el voto

# %% [markdown]
# ## Instalaciones
# Estamos suponiendo que estás en un entorno de Linux. Se puede hacer en WSL. No probamos compatibilidad con Mac.
# ### Zokrates
# Para generar las ZKP
# ```bash
# curl -LSfs get.zokrat.es | sh
# ```
#
# ```bash
#
# ```
# ```bash
#
# ```
# ```bash
#
# ```

# %% [markdown]
# ## Declaración de variables
# Completar la siguiente celda con tu token de voto

# %%
# Variables privadas - CAMBIAR POR VALORES REALES
token = [
0x01234567,
0x89abcdef,
0x01234567,
0x89abcdef,
0x01234567,
0x89abcdef,
0x01234567,
0x889abcdef
]

tokenHash = [
    0x89abcdef,
    0x01234567,
    0x89abcdef,
    0x01234567,
    0x89abcdef,
    0x01234567,
    0x889abcdef,
    0x01234567
]
